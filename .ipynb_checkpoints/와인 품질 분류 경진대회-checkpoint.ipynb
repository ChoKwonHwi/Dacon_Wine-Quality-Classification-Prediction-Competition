# %% [markdown]
# # 1. 필요 library import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import xgboost as xgb
import shap
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
warnings.simplefilter(action='ignore')

# %% [markdown]
# # 2. Data 불러오기

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# - index : 구분자
# - quality : 품질
# - fixed acidity : 산도
# - volatile acidity : 휘발성산
# - citric acid : 시트르산
# - residual sugar : 잔당 (발효 후 와인 속에 남아있는 당분)
# - chlorides : 염화물
# - free sulfur dioxide : 독립 이산화황
# - total sulfur dioxide : 총 이산화황
# - density : 밀도
# - pH : 수소이온농도
# - sulphates : 황산염
# - alcohol : 도수
# - type : 종류

# %%
train_data = pd.read_csv("./train.csv")
train_data
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# ...

# %%
train_data.info() #데이터 자료형 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5497 entries, 0 to 5496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 5497 non-null   int64
#  1   quality               5497 non-null   int64
#  2   fixed acidity         5497 non-null   float64
#  3   volatile acidity      5497 non-null   float64
#  4   citric acid           5497 non-null   float64
#  5   residual sugar        5497 non-null   float64
#  6   chlorides             5497 non-null   float64
#  7   free sulfur dioxide   5497 non-null   float64
#  8   total sulfur dioxide  5497 non-null   float64
#  9   density               5497 non-null   float64
#  10  pH                    5497 non-null   float64
#  11  sulphates             5497 non-null   float64
#  12  alcohol               5497 non-null   float64
#  13  type                  5497 non-null   object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
train_data.isna().sum()
# Out:
# index                   0
# quality                 0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# type                    0
# dtype: int64

# %%
train_data.describe()
# Out:
#              index      quality  fixed acidity  volatile acidity  citric acid  \
# count  5497.000000  5497.000000    5497.000000       5497.000000  5497.000000
# mean   2748.000000     5.818992       7.210115          0.338163     0.318543
# std    1586.991546     0.870311       1.287579          0.163224     0.145104
# min       0.000000     3.000000       3.800000          0.080000     0.000000
# 25%    1374.000000     5.000000       6.400000          0.230000     0.250000
# 50%    2748.000000     6.000000       7.000000          0.290000     0.310000
# 75%    4122.000000     6.000000       7.700000          0.400000     0.390000
# max    5496.000000     9.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     5497.000000  5497.000000          5497.000000           5497.000000
# mean         5.438075     0.055808            30.417682            115.566491
# ...

# %%
train_data.describe(include=['O']) #범주형 데이터 확인
# Out:
#          type
# count    5497
# unique      2
# top     white
# freq     4159

# %%
train_data.hist(figsize = (16, 12))
plt.show()

# %% [markdown]
# - id를 제외한 다른 지표들의 단위가 다 다르므로 추후 표준화 진행 예정
# - 등급, id 제외 유사한 분포를 가지는 속성들이 있는 것을 확인

# %% [markdown]
# # 3. Data 분석

# %%
train_data['type'].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
lab_enc = LabelEncoder()
train_data['type'] = lab_enc.fit_transform(train_data['type'])
train_data['type'].unique()
# Out:
# array([1, 0])

# %%
plt.figure(figsize = (20, 16))
x = sns.heatmap(train_data.corr(), cmap = 'Blues', linewidths = '0.1',annot = True)

# %%
sns.pairplot(train_data[['type', 'index', 'quality', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 
                                  'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates',
                                  'alcohol']] ,hue='type', palette='husl', markers=['o','s'])
plt.show()

# %%
scaler = preprocessing.MinMaxScaler()
normalized_data = scaler.fit_transform(train_data)
col = ['index', 'quality', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'type']
normalized_train = pd.DataFrame(normalized_data, columns = col)
normalized_train
# Out:
#          index   quality  fixed acidity  volatile acidity  citric acid  \
# 0     0.000000  0.333333       0.148760          0.410000     0.036145
# 1     0.000182  0.333333       0.413223          0.353333     0.084337
# 2     0.000364  0.333333       0.338843          0.086667     0.234940
# 3     0.000546  0.500000       0.264463          0.086667     0.186747
# 4     0.000728  0.500000       0.330579          0.213333     0.156627
# ...        ...       ...            ...               ...          ...
# 5492  0.999272  0.333333       0.322314          0.046667     0.174699
# 5493  0.999454  0.500000       0.206612          0.066667     0.216867
# 5494  0.999636  0.666667       0.330579          0.046667     0.204819
# 5495  0.999818  0.333333       0.231405          0.220000     0.186747
# 5496  1.000000  0.500000       0.264463          0.180000     0.102410
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# ...

# %% [markdown]
# # 4. Modeling

# %%
y_target = normalized_train['type']
x_data = normalized_train.drop(['index', 'type'], axis = 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_target, test_size = 0.2, random_state = 4)

# %%
# Out:
# 0.990909090909091

# %%
params = {
    'max_depth':[4, 6, 8, 10, 12],
    'min_child_weight':[4, 6, 8, 10],
    'gamma' : [0, 1, 2],
    'colsample_bytree':[0.7, 0.8, 0.9],
    'n_estimators':[10, 50, 100, 200, 300],
    'eta' : [0.1, 0.15, 0.2, 0.3]
}

grid_xgb_clf = xgb.XGBClassifier(random_state = 4, n_jobs = -1)
grid_cv = GridSearchCV(grid_xgb_clf, param_grid = params, cv = 5, n_jobs = -1)
grid_cv.fit(x_train, y_train)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'colsample_bytree': 0.7, 'eta': 0.3, 'gamma': 0, 'max_depth': 6, 'min_child_weight': 4, 'n_estimators': 100}
# 최고 예측 정확도: 0.9961

# %%
xgb_model = xgb.XGBClassifier(eta = 0.3, gamma = 0, max_depth = 6, min_child_weight = 4, n_estimators = 100, colsample_bytree = 0.7, random_state=4)

xgb_model.fit(x_train,y_train)
prediction = xgb_model.predict(x_test)
xgb_score = xgb_model.score(x_test, y_test)
xgb_score
# Out:
# 0.9936363636363637

# %%
# feature importance

ftr_importances_values = xgb_model.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index = x_train.columns)
ftr_sort = ftr_importances.sort_values(ascending=False)

plt.figure(figsize=(12,10))
plt.title('Feature Importances')
sns.barplot(x=ftr_sort, y=ftr_sort.index)
plt.show()
